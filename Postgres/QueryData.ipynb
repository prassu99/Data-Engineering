# %%
# import postgresql client
import psycopg2
from psycopg2 import sql
import random
# import the connect.py module
from connect import connect

# %%
# create a table
# cur.execute("""create table if not exists orders (
#         order_id serial primary key,
#         customer_id int,
#         status varchar(50),
#         quqantity int,
#         order_date date,
#         unit_price decimal(10, 2)
#     )
# """)

# select all records from the table
conn = connect()
cur=conn.cursor()
rows = cur.execute("SELECT * FROM orders")
print(rows)
# print(rows)
# insert 100 randon records into the table
for i in range(100):
    cur.execute(
        sql.SQL("INSERT INTO orders (customer_id, status, quqantity, order_date, unit_price) VALUES (%s, %s, %s, %s, %s)"),
        (random.randint(1, 10), 'finished', random.randint(1, 10), '2024-'+str(random.randint(1, 12))+'-'+str(random.randint(1, 28)), random.randint(1, 100))
    )

# commit the changes
conn.commit()
# read the records from the table
cur.execute("SELECT * FROM orders")
rows = cur.fetchall()
# print the records
for row in rows:
    print(row)
# close the cursor and connection
cur.close()
conn.close()
# Out:
# None
# (301, 3, 'finished', 5, datetime.date(2024, 6, 20), Decimal('78.00'))
# (302, 10, 'finished', 4, datetime.date(2024, 8, 23), Decimal('64.00'))
# (303, 5, 'finished', 10, datetime.date(2024, 10, 1), Decimal('39.00'))
# (304, 7, 'finished', 4, datetime.date(2024, 10, 9), Decimal('83.00'))
# (305, 1, 'finished', 3, datetime.date(2024, 6, 24), Decimal('53.00'))
# (306, 7, 'finished', 2, datetime.date(2024, 9, 13), Decimal('99.00'))
# (307, 6, 'finished', 1, datetime.date(2024, 7, 2), Decimal('11.00'))
# (308, 4, 'finished', 2, datetime.date(2024, 6, 27), Decimal('16.00'))
# (309, 4, 'finished', 1, datetime.date(2024, 5, 9), Decimal('77.00'))
# (310, 1, 'finished', 1, datetime.date(2024, 4, 16), Decimal('71.00'))
# (311, 1, 'finished', 3, datetime.date(2024, 11, 13), Decimal('19.00'))
# (312, 5, 'finished', 10, datetime.date(2024, 11, 9), Decimal('47.00'))
# (313, 3, 'finished', 4, datetime.date(2024, 3, 10), Decimal('4.00'))
# (314, 7, 'finished', 1, datetime.date(2024, 1, 6), Decimal('23.00'))
# (315, 8, 'finished', 7, datetime.date(2024, 12, 17), Decimal('8.00'))
# (316, 4, 'finished', 8, datetime.date(2024, 6, 9), Decimal('33.00'))
# (317, 10, 'finished', 2, datetime.date(2024, 6, 9), Decimal('24.00'))
# (318, 7, 'finished', 4, datetime.date(2024, 7, 10), Decimal('80.00'))
# (319, 3, 'finished', 5, datetime.date(2024, 6, 2), Decimal('50.00'))
# (320, 4, 'finished', 10, datetime.date(2024, 1, 12), Decimal('95.00'))
# (321, 9, 'finished', 2, datetime.date(2024, 5, 26), Decimal('19.00'))
# (322, 9, 'finished', 5, datetime.date(2024, 8, 26), Decimal('99.00'))
# (323, 1, 'finished', 5, datetime.date(2024, 5, 22), Decimal('17.00'))
# (324, 1, 'finished', 4, datetime.date(2024, 7, 9), Decimal('1.00'))
# (325, 3, 'finished', 10, datetime.date(2024, 4, 4), Decimal('4.00'))
# (326, 10, 'finished', 10, datetime.date(2024, 5, 9), Decimal('10.00'))
# (327, 10, 'finished', 2, datetime.date(2024, 8, 3), Decimal('69.00'))
# (328, 4, 'finished', 8, datetime.date(2024, 8, 18), Decimal('6.00'))
# (329, 2, 'finished', 1, datetime.date(2024, 6, 10), Decimal('28.00'))
# (330, 8, 'finished', 6, datetime.date(2024, 3, 17), Decimal('9.00'))
# (331, 3, 'finished', 5, datetime.date(2024, 12, 15), Decimal('60.00'))
# (332, 7, 'finished', 10, datetime.date(2024, 5, 12), Decimal('56.00'))
# (333, 1, 'finished', 7, datetime.date(2024, 4, 11), Decimal('50.00'))
# (334, 9, 'finished', 2, datetime.date(2024, 5, 23), Decimal('56.00'))
# (335, 4, 'finished', 3, datetime.date(2024, 2, 9), Decimal('80.00'))
# (336, 9, 'finished', 3, datetime.date(2024, 12, 26), Decimal('53.00'))
# (337, 6, 'finished', 2, datetime.date(2024, 6, 10), Decimal('18.00'))
# (338, 3, 'finished', 2, datetime.date(2024, 4, 20), Decimal('85.00'))
# (339, 2, 'finished', 2, datetime.date(2024, 9, 7), Decimal('55.00'))
# (340, 1, 'finished', 5, datetime.date(2024, 2, 16), Decimal('78.00'))
# (341, 1, 'finished', 3, datetime.date(2024, 1, 23), Decimal('63.00'))
# (342, 5, 'finished', 8, datetime.date(2024, 2, 23), Decimal('51.00'))
# (343, 2, 'finished', 6, datetime.date(2024, 9, 19), Decimal('100.00'))
# (344, 6, 'finished', 7, datetime.date(2024, 7, 15), Decimal('69.00'))
# (345, 7, 'finished', 4, datetime.date(2024, 12, 26), Decimal('66.00'))
# (346, 8, 'finished', 8, datetime.date(2024, 4, 2), Decimal('19.00'))
# (347, 7, 'finished', 1, datetime.date(2024, 1, 18), Decimal('100.00'))
# (348, 1, 'finished', 2, datetime.date(2024, 5, 12), Decimal('21.00'))
# (349, 5, 'finished', 9, datetime.date(2024, 1, 5), Decimal('91.00'))
# (350, 2, 'finished', 10, datetime.date(2024, 4, 8), Decimal('90.00'))
# (351, 7, 'finished', 7, datetime.date(2024, 9, 6), Decimal('51.00'))
# (352, 1, 'finished', 6, datetime.date(2024, 10, 24), Decimal('97.00'))
# (353, 7, 'finished', 3, datetime.date(2024, 1, 4), Decimal('41.00'))
# (354, 3, 'finished', 5, datetime.date(2024, 7, 23), Decimal('48.00'))
# (355, 6, 'finished', 7, datetime.date(2024, 3, 25), Decimal('54.00'))
# (356, 4, 'finished', 8, datetime.date(2024, 11, 27), Decimal('20.00'))
# (357, 9, 'finished', 10, datetime.date(2024, 11, 20), Decimal('64.00'))
# (358, 9, 'finished', 3, datetime.date(2024, 7, 11), Decimal('91.00'))
# (359, 8, 'finished', 9, datetime.date(2024, 3, 12), Decimal('41.00'))
# (360, 6, 'finished', 7, datetime.date(2024, 5, 4), Decimal('89.00'))
# (361, 3, 'finished', 7, datetime.date(2024, 11, 21), Decimal('72.00'))
# (362, 4, 'finished', 8, datetime.date(2024, 10, 24), Decimal('34.00'))
# (363, 7, 'finished', 7, datetime.date(2024, 3, 26), Decimal('63.00'))
# (364, 5, 'finished', 7, datetime.date(2024, 9, 17), Decimal('17.00'))
# (365, 2, 'finished', 7, datetime.date(2024, 11, 19), Decimal('10.00'))
# (366, 1, 'finished', 1, datetime.date(2024, 3, 23), Decimal('70.00'))
# (367, 3, 'finished', 2, datetime.date(2024, 6, 12), Decimal('53.00'))
# (368, 1, 'finished', 4, datetime.date(2024, 11, 26), Decimal('9.00'))
# (369, 8, 'finished', 10, datetime.date(2024, 3, 10), Decimal('2.00'))
# (370, 1, 'finished', 3, datetime.date(2024, 10, 20), Decimal('97.00'))
# (371, 7, 'finished', 4, datetime.date(2024, 6, 11), Decimal('81.00'))
# (372, 2, 'finished', 2, datetime.date(2024, 3, 17), Decimal('18.00'))
# (373, 10, 'finished', 7, datetime.date(2024, 3, 9), Decimal('33.00'))
# (374, 10, 'finished', 6, datetime.date(2024, 1, 6), Decimal('12.00'))
# (375, 6, 'finished', 9, datetime.date(2024, 6, 14), Decimal('45.00'))
# (376, 7, 'finished', 5, datetime.date(2024, 2, 1), Decimal('91.00'))
# (377, 5, 'finished', 4, datetime.date(2024, 10, 10), Decimal('9.00'))
# (378, 9, 'finished', 1, datetime.date(2024, 3, 27), Decimal('43.00'))
# (379, 7, 'finished', 10, datetime.date(2024, 11, 26), Decimal('56.00'))
# (380, 2, 'finished', 6, datetime.date(2024, 8, 19), Decimal('42.00'))
# (381, 8, 'finished', 8, datetime.date(2024, 9, 12), Decimal('98.00'))
# (382, 4, 'finished', 3, datetime.date(2024, 2, 19), Decimal('11.00'))
# (383, 7, 'finished', 6, datetime.date(2024, 11, 4), Decimal('43.00'))
# (384, 6, 'finished', 5, datetime.date(2024, 12, 15), Decimal('7.00'))
# (385, 7, 'finished', 3, datetime.date(2024, 3, 3), Decimal('60.00'))
# (386, 2, 'finished', 3, datetime.date(2024, 1, 22), Decimal('44.00'))
# (387, 9, 'finished', 9, datetime.date(2024, 1, 10), Decimal('50.00'))
# (388, 9, 'finished', 8, datetime.date(2024, 9, 9), Decimal('97.00'))
# (389, 7, 'finished', 5, datetime.date(2024, 12, 27), Decimal('56.00'))
# (390, 1, 'finished', 9, datetime.date(2024, 3, 2), Decimal('58.00'))
# (391, 2, 'finished', 8, datetime.date(2024, 9, 14), Decimal('51.00'))
# (392, 5, 'finished', 7, datetime.date(2024, 7, 19), Decimal('96.00'))
# (393, 3, 'finished', 1, datetime.date(2024, 6, 7), Decimal('67.00'))
# (394, 7, 'finished', 10, datetime.date(2024, 2, 12), Decimal('10.00'))
# (395, 5, 'finished', 3, datetime.date(2024, 5, 26), Decimal('21.00'))
# (396, 3, 'finished', 2, datetime.date(2024, 1, 24), Decimal('5.00'))
# (397, 1, 'finished', 4, datetime.date(2024, 12, 11), Decimal('55.00'))
# (398, 5, 'finished', 2, datetime.date(2024, 7, 13), Decimal('51.00'))
# (399, 5, 'finished', 3, datetime.date(2024, 3, 3), Decimal('97.00'))
# (400, 10, 'finished', 4, datetime.date(2024, 1, 1), Decimal('89.00'))
# (401, 5, 'finished', 4, datetime.date(2024, 11, 14), Decimal('24.00'))
# (402, 6, 'finished', 10, datetime.date(2024, 8, 13), Decimal('22.00'))
# (403, 3, 'finished', 9, datetime.date(2024, 5, 23), Decimal('26.00'))
# (404, 8, 'finished', 9, datetime.date(2024, 4, 12), Decimal('50.00'))
# (405, 3, 'finished', 5, datetime.date(2024, 2, 20), Decimal('66.00'))
# (406, 9, 'finished', 4, datetime.date(2024, 9, 17), Decimal('7.00'))
# (407, 2, 'finished', 4, datetime.date(2024, 9, 12), Decimal('88.00'))
# (408, 9, 'finished', 6, datetime.date(2024, 10, 8), Decimal('54.00'))
# (409, 3, 'finished', 6, datetime.date(2024, 6, 8), Decimal('15.00'))
# (410, 4, 'finished', 6, datetime.date(2024, 4, 25), Decimal('76.00'))
# (411, 1, 'finished', 9, datetime.date(2024, 6, 4), Decimal('2.00'))
# (412, 5, 'finished', 1, datetime.date(2024, 5, 23), Decimal('34.00'))
# (413, 3, 'finished', 8, datetime.date(2024, 9, 18), Decimal('16.00'))
# (414, 10, 'finished', 8, datetime.date(2024, 9, 13), Decimal('71.00'))
# (415, 7, 'finished', 9, datetime.date(2024, 5, 4), Decimal('6.00'))
# (416, 8, 'finished', 10, datetime.date(2024, 2, 13), Decimal('59.00'))
# (417, 2, 'finished', 2, datetime.date(2024, 7, 11), Decimal('71.00'))
# (418, 4, 'finished', 7, datetime.date(2024, 11, 9), Decimal('66.00'))
# (419, 8, 'finished', 6, datetime.date(2024, 4, 19), Decimal('33.00'))
# (420, 8, 'finished', 4, datetime.date(2024, 12, 10), Decimal('25.00'))
# (421, 4, 'finished', 8, datetime.date(2024, 1, 13), Decimal('18.00'))
# (422, 2, 'finished', 3, datetime.date(2024, 2, 20), Decimal('99.00'))
# (423, 7, 'finished', 5, datetime.date(2024, 10, 24), Decimal('22.00'))
# (424, 7, 'finished', 6, datetime.date(2024, 7, 25), Decimal('65.00'))
# (425, 10, 'finished', 5, datetime.date(2024, 2, 6), Decimal('55.00'))
# (426, 6, 'finished', 9, datetime.date(2024, 7, 17), Decimal('27.00'))
# (427, 10, 'finished', 3, datetime.date(2024, 12, 2), Decimal('15.00'))
# (428, 10, 'finished', 4, datetime.date(2024, 4, 8), Decimal('35.00'))
# (429, 3, 'finished', 5, datetime.date(2024, 9, 23), Decimal('44.00'))
# (430, 5, 'finished', 3, datetime.date(2024, 11, 6), Decimal('34.00'))
# (431, 2, 'finished', 8, datetime.date(2024, 8, 20), Decimal('58.00'))
# (432, 3, 'finished', 2, datetime.date(2024, 2, 26), Decimal('74.00'))
# (433, 5, 'finished', 7, datetime.date(2024, 6, 14), Decimal('20.00'))
# (434, 5, 'finished', 10, datetime.date(2024, 10, 12), Decimal('37.00'))
# (435, 10, 'finished', 6, datetime.date(2024, 1, 24), Decimal('14.00'))
# (436, 8, 'finished', 9, datetime.date(2024, 11, 4), Decimal('7.00'))
# (437, 1, 'finished', 1, datetime.date(2024, 7, 28), Decimal('63.00'))
# (438, 7, 'finished', 8, datetime.date(2024, 6, 17), Decimal('55.00'))
# (439, 1, 'finished', 7, datetime.date(2024, 1, 9), Decimal('81.00'))
# (440, 6, 'finished', 3, datetime.date(2024, 11, 26), Decimal('86.00'))
# (441, 2, 'finished', 2, datetime.date(2024, 10, 5), Decimal('6.00'))
# (442, 1, 'finished', 4, datetime.date(2024, 2, 17), Decimal('60.00'))
# (443, 6, 'finished', 6, datetime.date(2024, 5, 8), Decimal('55.00'))
# (444, 2, 'finished', 3, datetime.date(2024, 7, 27), Decimal('53.00'))
# (445, 3, 'finished', 1, datetime.date(2024, 2, 27), Decimal('43.00'))
# (446, 10, 'finished', 8, datetime.date(2024, 9, 23), Decimal('14.00'))
# (447, 2, 'finished', 3, datetime.date(2024, 3, 5), Decimal('99.00'))
# (448, 4, 'finished', 9, datetime.date(2024, 10, 9), Decimal('9.00'))
# (449, 9, 'finished', 7, datetime.date(2024, 1, 7), Decimal('75.00'))
# (450, 1, 'finished', 2, datetime.date(2024, 1, 13), Decimal('13.00'))
# (451, 4, 'finished', 4, datetime.date(2024, 8, 20), Decimal('1.00'))
# (452, 9, 'finished', 8, datetime.date(2024, 8, 13), Decimal('9.00'))
# (453, 9, 'finished', 3, datetime.date(2024, 6, 12), Decimal('28.00'))
# (454, 4, 'finished', 3, datetime.date(2024, 9, 5), Decimal('37.00'))
# (455, 5, 'finished', 5, datetime.date(2024, 7, 24), Decimal('93.00'))
# (456, 10, 'finished', 3, datetime.date(2024, 8, 10), Decimal('78.00'))
# (457, 1, 'finished', 1, datetime.date(2024, 2, 17), Decimal('34.00'))
# (458, 3, 'finished', 3, datetime.date(2024, 4, 27), Decimal('40.00'))
# (459, 9, 'finished', 5, datetime.date(2024, 11, 28), Decimal('62.00'))
# (460, 8, 'finished', 3, datetime.date(2024, 7, 21), Decimal('74.00'))
# (461, 3, 'finished', 1, datetime.date(2024, 5, 12), Decimal('71.00'))
# (462, 4, 'finished', 6, datetime.date(2024, 1, 21), Decimal('21.00'))
# (463, 8, 'finished', 6, datetime.date(2024, 6, 16), Decimal('54.00'))
# (464, 7, 'finished', 4, datetime.date(2024, 3, 13), Decimal('65.00'))
# (465, 7, 'finished', 8, datetime.date(2024, 3, 24), Decimal('39.00'))
# (466, 8, 'finished', 8, datetime.date(2024, 6, 11), Decimal('66.00'))
# (467, 5, 'finished', 10, datetime.date(2024, 12, 5), Decimal('40.00'))
# (468, 9, 'finished', 2, datetime.date(2024, 12, 17), Decimal('58.00'))
# (469, 4, 'finished', 5, datetime.date(2024, 4, 10), Decimal('28.00'))
# (470, 4, 'finished', 10, datetime.date(2024, 6, 10), Decimal('71.00'))
# (471, 7, 'finished', 9, datetime.date(2024, 11, 25), Decimal('80.00'))
# (472, 9, 'finished', 8, datetime.date(2024, 8, 6), Decimal('78.00'))
# (473, 1, 'finished', 3, datetime.date(2024, 7, 15), Decimal('98.00'))
# (474, 2, 'finished', 2, datetime.date(2024, 11, 17), Decimal('25.00'))
# (475, 8, 'finished', 9, datetime.date(2024, 4, 25), Decimal('46.00'))
# (476, 10, 'finished', 7, datetime.date(2024, 8, 1), Decimal('88.00'))
# (477, 3, 'finished', 9, datetime.date(2024, 7, 9), Decimal('32.00'))
# (478, 10, 'finished', 4, datetime.date(2024, 7, 24), Decimal('51.00'))
# (479, 2, 'finished', 10, datetime.date(2024, 5, 11), Decimal('42.00'))
# (480, 9, 'finished', 6, datetime.date(2024, 11, 16), Decimal('38.00'))
# (481, 3, 'finished', 9, datetime.date(2024, 7, 24), Decimal('66.00'))
# (482, 9, 'finished', 3, datetime.date(2024, 6, 9), Decimal('91.00'))
# (483, 10, 'finished', 9, datetime.date(2024, 12, 16), Decimal('22.00'))
# (484, 6, 'finished', 10, datetime.date(2024, 6, 7), Decimal('67.00'))
# (485, 10, 'finished', 6, datetime.date(2024, 9, 13), Decimal('60.00'))
# (486, 6, 'finished', 6, datetime.date(2024, 9, 18), Decimal('8.00'))
# (487, 5, 'finished', 5, datetime.date(2024, 6, 7), Decimal('54.00'))
# (488, 6, 'finished', 3, datetime.date(2024, 4, 19), Decimal('14.00'))
# (489, 6, 'finished', 10, datetime.date(2024, 6, 28), Decimal('70.00'))
# (490, 1, 'finished', 6, datetime.date(2024, 6, 6), Decimal('22.00'))
# (491, 7, 'finished', 5, datetime.date(2024, 4, 7), Decimal('48.00'))
# (492, 5, 'finished', 3, datetime.date(2024, 4, 25), Decimal('21.00'))
# (493, 5, 'finished', 6, datetime.date(2024, 10, 13), Decimal('50.00'))
# (494, 7, 'finished', 4, datetime.date(2024, 8, 26), Decimal('92.00'))
# (495, 6, 'finished', 6, datetime.date(2024, 3, 23), Decimal('60.00'))
# (496, 1, 'finished', 2, datetime.date(2024, 7, 18), Decimal('55.00'))
# (497, 6, 'finished', 5, datetime.date(2024, 11, 7), Decimal('66.00'))
# (498, 10, 'finished', 7, datetime.date(2024, 7, 27), Decimal('71.00'))
# (499, 9, 'finished', 10, datetime.date(2024, 7, 19), Decimal('61.00'))
# (500, 2, 'finished', 1, datetime.date(2024, 3, 20), Decimal('41.00'))
# (501, 2, 'finished', 2, datetime.date(2024, 4, 12), Decimal('26.00'))
# (502, 4, 'finished', 10, datetime.date(2024, 5, 22), Decimal('68.00'))
# (503, 4, 'finished', 1, datetime.date(2024, 12, 22), Decimal('87.00'))
# (504, 6, 'finished', 5, datetime.date(2024, 3, 12), Decimal('59.00'))
# (505, 9, 'finished', 7, datetime.date(2024, 12, 16), Decimal('38.00'))
# (506, 1, 'finished', 7, datetime.date(2024, 7, 22), Decimal('1.00'))
# (507, 2, 'finished', 9, datetime.date(2024, 5, 5), Decimal('23.00'))
# (508, 3, 'finished', 8, datetime.date(2024, 6, 8), Decimal('7.00'))
# (509, 9, 'finished', 2, datetime.date(2024, 9, 16), Decimal('14.00'))
# (510, 5, 'finished', 5, datetime.date(2024, 9, 12), Decimal('49.00'))
# (511, 8, 'finished', 10, datetime.date(2024, 3, 28), Decimal('39.00'))
# (512, 7, 'finished', 9, datetime.date(2024, 12, 1), Decimal('98.00'))
# (513, 10, 'finished', 6, datetime.date(2024, 9, 24), Decimal('49.00'))
# (514, 9, 'finished', 9, datetime.date(2024, 3, 28), Decimal('15.00'))
# (515, 9, 'finished', 9, datetime.date(2024, 1, 11), Decimal('65.00'))
# (516, 3, 'finished', 3, datetime.date(2024, 6, 21), Decimal('60.00'))
# (517, 6, 'finished', 5, datetime.date(2024, 1, 27), Decimal('41.00'))
# (518, 9, 'finished', 9, datetime.date(2024, 5, 16), Decimal('84.00'))
# (519, 3, 'finished', 4, datetime.date(2024, 6, 22), Decimal('40.00'))
# (520, 3, 'finished', 7, datetime.date(2024, 3, 26), Decimal('11.00'))
# (521, 3, 'finished', 10, datetime.date(2024, 5, 11), Decimal('41.00'))
# (522, 10, 'finished', 3, datetime.date(2024, 3, 14), Decimal('16.00'))
# (523, 9, 'finished', 2, datetime.date(2024, 1, 18), Decimal('94.00'))
# (524, 5, 'finished', 5, datetime.date(2024, 4, 16), Decimal('17.00'))
# (525, 3, 'finished', 2, datetime.date(2024, 11, 27), Decimal('50.00'))
# (526, 9, 'finished', 6, datetime.date(2024, 3, 25), Decimal('56.00'))
# (527, 10, 'finished', 2, datetime.date(2024, 9, 1), Decimal('36.00'))
# (528, 3, 'finished', 2, datetime.date(2024, 1, 4), Decimal('7.00'))
# (529, 4, 'finished', 4, datetime.date(2024, 10, 27), Decimal('84.00'))
# (530, 9, 'finished', 9, datetime.date(2024, 1, 4), Decimal('49.00'))
# (531, 4, 'finished', 8, datetime.date(2024, 7, 14), Decimal('8.00'))
# (532, 5, 'finished', 1, datetime.date(2024, 4, 8), Decimal('42.00'))
# (533, 9, 'finished', 6, datetime.date(2024, 4, 12), Decimal('77.00'))
# (534, 7, 'finished', 3, datetime.date(2024, 6, 15), Decimal('72.00'))
# (535, 9, 'finished', 5, datetime.date(2024, 12, 12), Decimal('71.00'))
# (536, 4, 'finished', 6, datetime.date(2024, 8, 4), Decimal('56.00'))
# (537, 8, 'finished', 6, datetime.date(2024, 2, 14), Decimal('61.00'))
# (538, 3, 'finished', 2, datetime.date(2024, 8, 2), Decimal('7.00'))
# (539, 6, 'finished', 1, datetime.date(2024, 10, 8), Decimal('82.00'))
# (540, 10, 'finished', 6, datetime.date(2024, 11, 7), Decimal('32.00'))
# (541, 10, 'finished', 8, datetime.date(2024, 8, 9), Decimal('40.00'))
# (542, 9, 'finished', 6, datetime.date(2024, 12, 15), Decimal('80.00'))
# (543, 1, 'finished', 9, datetime.date(2024, 7, 24), Decimal('16.00'))
# (544, 10, 'finished', 4, datetime.date(2024, 8, 16), Decimal('40.00'))
# (545, 2, 'finished', 8, datetime.date(2024, 12, 12), Decimal('45.00'))
# (546, 9, 'finished', 10, datetime.date(2024, 8, 20), Decimal('78.00'))
# (547, 7, 'finished', 3, datetime.date(2024, 8, 28), Decimal('34.00'))
# (548, 3, 'finished', 7, datetime.date(2024, 3, 7), Decimal('70.00'))
# (549, 10, 'finished', 5, datetime.date(2024, 2, 1), Decimal('56.00'))
# (550, 6, 'finished', 8, datetime.date(2024, 6, 27), Decimal('35.00'))
# (551, 3, 'finished', 3, datetime.date(2024, 2, 18), Decimal('95.00'))
# (552, 9, 'finished', 3, datetime.date(2024, 10, 19), Decimal('97.00'))
# (553, 8, 'finished', 8, datetime.date(2024, 7, 18), Decimal('22.00'))
# (554, 8, 'finished', 2, datetime.date(2024, 6, 15), Decimal('76.00'))
# (555, 7, 'finished', 9, datetime.date(2024, 10, 21), Decimal('47.00'))
# (556, 5, 'finished', 1, datetime.date(2024, 7, 14), Decimal('44.00'))
# (557, 6, 'finished', 1, datetime.date(2024, 2, 12), Decimal('67.00'))
# (558, 2, 'finished', 6, datetime.date(2024, 3, 20), Decimal('15.00'))
# (559, 5, 'finished', 3, datetime.date(2024, 10, 16), Decimal('61.00'))
# (560, 8, 'finished', 6, datetime.date(2024, 8, 11), Decimal('16.00'))
# (561, 5, 'finished', 7, datetime.date(2024, 2, 24), Decimal('37.00'))
# (562, 10, 'finished', 3, datetime.date(2024, 12, 10), Decimal('99.00'))
# (563, 1, 'finished', 5, datetime.date(2024, 7, 21), Decimal('14.00'))
# (564, 9, 'finished', 6, datetime.date(2024, 7, 13), Decimal('72.00'))
# (565, 4, 'finished', 9, datetime.date(2024, 11, 13), Decimal('33.00'))
# (566, 8, 'finished', 1, datetime.date(2024, 12, 7), Decimal('40.00'))
# (567, 4, 'finished', 6, datetime.date(2024, 4, 15), Decimal('55.00'))
# (568, 9, 'finished', 4, datetime.date(2024, 10, 7), Decimal('51.00'))
# (569, 1, 'finished', 7, datetime.date(2024, 4, 11), Decimal('76.00'))
# (570, 6, 'finished', 8, datetime.date(2024, 8, 21), Decimal('33.00'))
# (571, 10, 'finished', 2, datetime.date(2024, 12, 4), Decimal('45.00'))
# (572, 8, 'finished', 7, datetime.date(2024, 2, 13), Decimal('28.00'))
# (573, 8, 'finished', 3, datetime.date(2024, 4, 2), Decimal('11.00'))
# (574, 2, 'finished', 6, datetime.date(2024, 7, 1), Decimal('62.00'))
# (575, 9, 'finished', 8, datetime.date(2024, 1, 7), Decimal('79.00'))
# (576, 1, 'finished', 8, datetime.date(2024, 12, 12), Decimal('27.00'))
# (577, 8, 'finished', 9, datetime.date(2024, 8, 22), Decimal('27.00'))
# (578, 1, 'finished', 2, datetime.date(2024, 2, 8), Decimal('83.00'))
# (579, 8, 'finished', 9, datetime.date(2024, 9, 4), Decimal('42.00'))
# (580, 5, 'finished', 9, datetime.date(2024, 7, 8), Decimal('30.00'))
# (581, 7, 'finished', 1, datetime.date(2024, 9, 6), Decimal('5.00'))
# (582, 3, 'finished', 2, datetime.date(2024, 8, 26), Decimal('74.00'))
# (583, 9, 'finished', 1, datetime.date(2024, 9, 4), Decimal('90.00'))
# (584, 4, 'finished', 9, datetime.date(2024, 1, 11), Decimal('23.00'))
# (585, 6, 'finished', 10, datetime.date(2024, 3, 6), Decimal('32.00'))
# (586, 7, 'finished', 6, datetime.date(2024, 1, 4), Decimal('54.00'))
# (587, 7, 'finished', 6, datetime.date(2024, 10, 18), Decimal('40.00'))
# (588, 10, 'finished', 6, datetime.date(2024, 8, 21), Decimal('61.00'))
# (589, 3, 'finished', 10, datetime.date(2024, 10, 22), Decimal('6.00'))
# (590, 3, 'finished', 4, datetime.date(2024, 11, 13), Decimal('41.00'))
# (591, 10, 'finished', 8, datetime.date(2024, 7, 16), Decimal('99.00'))
# (592, 9, 'finished', 4, datetime.date(2024, 2, 27), Decimal('42.00'))
# (593, 7, 'finished', 6, datetime.date(2024, 12, 7), Decimal('29.00'))
# (594, 4, 'finished', 8, datetime.date(2024, 4, 12), Decimal('6.00'))
# (595, 4, 'finished', 2, datetime.date(2024, 9, 20), Decimal('67.00'))
# (596, 9, 'finished', 7, datetime.date(2024, 11, 13), Decimal('37.00'))
# (597, 5, 'finished', 2, datetime.date(2024, 11, 18), Decimal('58.00'))
# (598, 7, 'finished', 2, datetime.date(2024, 7, 22), Decimal('84.00'))
# (599, 2, 'finished', 8, datetime.date(2024, 11, 9), Decimal('23.00'))
# (600, 1, 'finished', 2, datetime.date(2024, 8, 9), Decimal('31.00'))

# %%
# cur.execute(
#         sql.SQL("Delete from orders ")
#     )
# # commit the changes
# conn.commit()
conn = connect()
cur=conn.cursor()
cur.execute(
        sql.SQL("select * from orders ")
    )
rows = cur.fetchall()
# print the records
for row in rows:
    print(row)
# close the cursor and connection
cur.close()
conn.close()
# Out:
# (301, 3, 'finished', 5, datetime.date(2024, 6, 20), Decimal('78.00'))
# (302, 10, 'finished', 4, datetime.date(2024, 8, 23), Decimal('64.00'))
# (303, 5, 'finished', 10, datetime.date(2024, 10, 1), Decimal('39.00'))
# (304, 7, 'finished', 4, datetime.date(2024, 10, 9), Decimal('83.00'))
# (305, 1, 'finished', 3, datetime.date(2024, 6, 24), Decimal('53.00'))
# (306, 7, 'finished', 2, datetime.date(2024, 9, 13), Decimal('99.00'))
# (307, 6, 'finished', 1, datetime.date(2024, 7, 2), Decimal('11.00'))
# (308, 4, 'finished', 2, datetime.date(2024, 6, 27), Decimal('16.00'))
# (309, 4, 'finished', 1, datetime.date(2024, 5, 9), Decimal('77.00'))
# (310, 1, 'finished', 1, datetime.date(2024, 4, 16), Decimal('71.00'))
# (311, 1, 'finished', 3, datetime.date(2024, 11, 13), Decimal('19.00'))
# (312, 5, 'finished', 10, datetime.date(2024, 11, 9), Decimal('47.00'))
# (313, 3, 'finished', 4, datetime.date(2024, 3, 10), Decimal('4.00'))
# (314, 7, 'finished', 1, datetime.date(2024, 1, 6), Decimal('23.00'))
# (315, 8, 'finished', 7, datetime.date(2024, 12, 17), Decimal('8.00'))
# (316, 4, 'finished', 8, datetime.date(2024, 6, 9), Decimal('33.00'))
# (317, 10, 'finished', 2, datetime.date(2024, 6, 9), Decimal('24.00'))
# (318, 7, 'finished', 4, datetime.date(2024, 7, 10), Decimal('80.00'))
# (319, 3, 'finished', 5, datetime.date(2024, 6, 2), Decimal('50.00'))
# (320, 4, 'finished', 10, datetime.date(2024, 1, 12), Decimal('95.00'))
# (321, 9, 'finished', 2, datetime.date(2024, 5, 26), Decimal('19.00'))
# (322, 9, 'finished', 5, datetime.date(2024, 8, 26), Decimal('99.00'))
# (323, 1, 'finished', 5, datetime.date(2024, 5, 22), Decimal('17.00'))
# (324, 1, 'finished', 4, datetime.date(2024, 7, 9), Decimal('1.00'))
# (325, 3, 'finished', 10, datetime.date(2024, 4, 4), Decimal('4.00'))
# (326, 10, 'finished', 10, datetime.date(2024, 5, 9), Decimal('10.00'))
# (327, 10, 'finished', 2, datetime.date(2024, 8, 3), Decimal('69.00'))
# (328, 4, 'finished', 8, datetime.date(2024, 8, 18), Decimal('6.00'))
# (329, 2, 'finished', 1, datetime.date(2024, 6, 10), Decimal('28.00'))
# (330, 8, 'finished', 6, datetime.date(2024, 3, 17), Decimal('9.00'))
# (331, 3, 'finished', 5, datetime.date(2024, 12, 15), Decimal('60.00'))
# (332, 7, 'finished', 10, datetime.date(2024, 5, 12), Decimal('56.00'))
# (333, 1, 'finished', 7, datetime.date(2024, 4, 11), Decimal('50.00'))
# (334, 9, 'finished', 2, datetime.date(2024, 5, 23), Decimal('56.00'))
# (335, 4, 'finished', 3, datetime.date(2024, 2, 9), Decimal('80.00'))
# (336, 9, 'finished', 3, datetime.date(2024, 12, 26), Decimal('53.00'))
# (337, 6, 'finished', 2, datetime.date(2024, 6, 10), Decimal('18.00'))
# (338, 3, 'finished', 2, datetime.date(2024, 4, 20), Decimal('85.00'))
# (339, 2, 'finished', 2, datetime.date(2024, 9, 7), Decimal('55.00'))
# (340, 1, 'finished', 5, datetime.date(2024, 2, 16), Decimal('78.00'))
# (341, 1, 'finished', 3, datetime.date(2024, 1, 23), Decimal('63.00'))
# (342, 5, 'finished', 8, datetime.date(2024, 2, 23), Decimal('51.00'))
# (343, 2, 'finished', 6, datetime.date(2024, 9, 19), Decimal('100.00'))
# (344, 6, 'finished', 7, datetime.date(2024, 7, 15), Decimal('69.00'))
# (345, 7, 'finished', 4, datetime.date(2024, 12, 26), Decimal('66.00'))
# (346, 8, 'finished', 8, datetime.date(2024, 4, 2), Decimal('19.00'))
# (347, 7, 'finished', 1, datetime.date(2024, 1, 18), Decimal('100.00'))
# (348, 1, 'finished', 2, datetime.date(2024, 5, 12), Decimal('21.00'))
# (349, 5, 'finished', 9, datetime.date(2024, 1, 5), Decimal('91.00'))
# (350, 2, 'finished', 10, datetime.date(2024, 4, 8), Decimal('90.00'))
# (351, 7, 'finished', 7, datetime.date(2024, 9, 6), Decimal('51.00'))
# (352, 1, 'finished', 6, datetime.date(2024, 10, 24), Decimal('97.00'))
# (353, 7, 'finished', 3, datetime.date(2024, 1, 4), Decimal('41.00'))
# (354, 3, 'finished', 5, datetime.date(2024, 7, 23), Decimal('48.00'))
# (355, 6, 'finished', 7, datetime.date(2024, 3, 25), Decimal('54.00'))
# (356, 4, 'finished', 8, datetime.date(2024, 11, 27), Decimal('20.00'))
# (357, 9, 'finished', 10, datetime.date(2024, 11, 20), Decimal('64.00'))
# (358, 9, 'finished', 3, datetime.date(2024, 7, 11), Decimal('91.00'))
# (359, 8, 'finished', 9, datetime.date(2024, 3, 12), Decimal('41.00'))
# (360, 6, 'finished', 7, datetime.date(2024, 5, 4), Decimal('89.00'))
# (361, 3, 'finished', 7, datetime.date(2024, 11, 21), Decimal('72.00'))
# (362, 4, 'finished', 8, datetime.date(2024, 10, 24), Decimal('34.00'))
# (363, 7, 'finished', 7, datetime.date(2024, 3, 26), Decimal('63.00'))
# (364, 5, 'finished', 7, datetime.date(2024, 9, 17), Decimal('17.00'))
# (365, 2, 'finished', 7, datetime.date(2024, 11, 19), Decimal('10.00'))
# (366, 1, 'finished', 1, datetime.date(2024, 3, 23), Decimal('70.00'))
# (367, 3, 'finished', 2, datetime.date(2024, 6, 12), Decimal('53.00'))
# (368, 1, 'finished', 4, datetime.date(2024, 11, 26), Decimal('9.00'))
# (369, 8, 'finished', 10, datetime.date(2024, 3, 10), Decimal('2.00'))
# (370, 1, 'finished', 3, datetime.date(2024, 10, 20), Decimal('97.00'))
# (371, 7, 'finished', 4, datetime.date(2024, 6, 11), Decimal('81.00'))
# (372, 2, 'finished', 2, datetime.date(2024, 3, 17), Decimal('18.00'))
# (373, 10, 'finished', 7, datetime.date(2024, 3, 9), Decimal('33.00'))
# (374, 10, 'finished', 6, datetime.date(2024, 1, 6), Decimal('12.00'))
# (375, 6, 'finished', 9, datetime.date(2024, 6, 14), Decimal('45.00'))
# (376, 7, 'finished', 5, datetime.date(2024, 2, 1), Decimal('91.00'))
# (377, 5, 'finished', 4, datetime.date(2024, 10, 10), Decimal('9.00'))
# (378, 9, 'finished', 1, datetime.date(2024, 3, 27), Decimal('43.00'))
# (379, 7, 'finished', 10, datetime.date(2024, 11, 26), Decimal('56.00'))
# (380, 2, 'finished', 6, datetime.date(2024, 8, 19), Decimal('42.00'))
# (381, 8, 'finished', 8, datetime.date(2024, 9, 12), Decimal('98.00'))
# (382, 4, 'finished', 3, datetime.date(2024, 2, 19), Decimal('11.00'))
# (383, 7, 'finished', 6, datetime.date(2024, 11, 4), Decimal('43.00'))
# (384, 6, 'finished', 5, datetime.date(2024, 12, 15), Decimal('7.00'))
# (385, 7, 'finished', 3, datetime.date(2024, 3, 3), Decimal('60.00'))
# (386, 2, 'finished', 3, datetime.date(2024, 1, 22), Decimal('44.00'))
# (387, 9, 'finished', 9, datetime.date(2024, 1, 10), Decimal('50.00'))
# (388, 9, 'finished', 8, datetime.date(2024, 9, 9), Decimal('97.00'))
# (389, 7, 'finished', 5, datetime.date(2024, 12, 27), Decimal('56.00'))
# (390, 1, 'finished', 9, datetime.date(2024, 3, 2), Decimal('58.00'))
# (391, 2, 'finished', 8, datetime.date(2024, 9, 14), Decimal('51.00'))
# (392, 5, 'finished', 7, datetime.date(2024, 7, 19), Decimal('96.00'))
# (393, 3, 'finished', 1, datetime.date(2024, 6, 7), Decimal('67.00'))
# (394, 7, 'finished', 10, datetime.date(2024, 2, 12), Decimal('10.00'))
# (395, 5, 'finished', 3, datetime.date(2024, 5, 26), Decimal('21.00'))
# (396, 3, 'finished', 2, datetime.date(2024, 1, 24), Decimal('5.00'))
# (397, 1, 'finished', 4, datetime.date(2024, 12, 11), Decimal('55.00'))
# (398, 5, 'finished', 2, datetime.date(2024, 7, 13), Decimal('51.00'))
# (399, 5, 'finished', 3, datetime.date(2024, 3, 3), Decimal('97.00'))
# (400, 10, 'finished', 4, datetime.date(2024, 1, 1), Decimal('89.00'))
# (401, 5, 'finished', 4, datetime.date(2024, 11, 14), Decimal('24.00'))
# (402, 6, 'finished', 10, datetime.date(2024, 8, 13), Decimal('22.00'))
# (403, 3, 'finished', 9, datetime.date(2024, 5, 23), Decimal('26.00'))
# (404, 8, 'finished', 9, datetime.date(2024, 4, 12), Decimal('50.00'))
# (405, 3, 'finished', 5, datetime.date(2024, 2, 20), Decimal('66.00'))
# (406, 9, 'finished', 4, datetime.date(2024, 9, 17), Decimal('7.00'))
# (407, 2, 'finished', 4, datetime.date(2024, 9, 12), Decimal('88.00'))
# (408, 9, 'finished', 6, datetime.date(2024, 10, 8), Decimal('54.00'))
# (409, 3, 'finished', 6, datetime.date(2024, 6, 8), Decimal('15.00'))
# (410, 4, 'finished', 6, datetime.date(2024, 4, 25), Decimal('76.00'))
# (411, 1, 'finished', 9, datetime.date(2024, 6, 4), Decimal('2.00'))
# (412, 5, 'finished', 1, datetime.date(2024, 5, 23), Decimal('34.00'))
# (413, 3, 'finished', 8, datetime.date(2024, 9, 18), Decimal('16.00'))
# (414, 10, 'finished', 8, datetime.date(2024, 9, 13), Decimal('71.00'))
# (415, 7, 'finished', 9, datetime.date(2024, 5, 4), Decimal('6.00'))
# (416, 8, 'finished', 10, datetime.date(2024, 2, 13), Decimal('59.00'))
# (417, 2, 'finished', 2, datetime.date(2024, 7, 11), Decimal('71.00'))
# (418, 4, 'finished', 7, datetime.date(2024, 11, 9), Decimal('66.00'))
# (419, 8, 'finished', 6, datetime.date(2024, 4, 19), Decimal('33.00'))
# (420, 8, 'finished', 4, datetime.date(2024, 12, 10), Decimal('25.00'))
# (421, 4, 'finished', 8, datetime.date(2024, 1, 13), Decimal('18.00'))
# (422, 2, 'finished', 3, datetime.date(2024, 2, 20), Decimal('99.00'))
# (423, 7, 'finished', 5, datetime.date(2024, 10, 24), Decimal('22.00'))
# (424, 7, 'finished', 6, datetime.date(2024, 7, 25), Decimal('65.00'))
# (425, 10, 'finished', 5, datetime.date(2024, 2, 6), Decimal('55.00'))
# (426, 6, 'finished', 9, datetime.date(2024, 7, 17), Decimal('27.00'))
# (427, 10, 'finished', 3, datetime.date(2024, 12, 2), Decimal('15.00'))
# (428, 10, 'finished', 4, datetime.date(2024, 4, 8), Decimal('35.00'))
# (429, 3, 'finished', 5, datetime.date(2024, 9, 23), Decimal('44.00'))
# (430, 5, 'finished', 3, datetime.date(2024, 11, 6), Decimal('34.00'))
# (431, 2, 'finished', 8, datetime.date(2024, 8, 20), Decimal('58.00'))
# (432, 3, 'finished', 2, datetime.date(2024, 2, 26), Decimal('74.00'))
# (433, 5, 'finished', 7, datetime.date(2024, 6, 14), Decimal('20.00'))
# (434, 5, 'finished', 10, datetime.date(2024, 10, 12), Decimal('37.00'))
# (435, 10, 'finished', 6, datetime.date(2024, 1, 24), Decimal('14.00'))
# (436, 8, 'finished', 9, datetime.date(2024, 11, 4), Decimal('7.00'))
# (437, 1, 'finished', 1, datetime.date(2024, 7, 28), Decimal('63.00'))
# (438, 7, 'finished', 8, datetime.date(2024, 6, 17), Decimal('55.00'))
# (439, 1, 'finished', 7, datetime.date(2024, 1, 9), Decimal('81.00'))
# (440, 6, 'finished', 3, datetime.date(2024, 11, 26), Decimal('86.00'))
# (441, 2, 'finished', 2, datetime.date(2024, 10, 5), Decimal('6.00'))
# (442, 1, 'finished', 4, datetime.date(2024, 2, 17), Decimal('60.00'))
# (443, 6, 'finished', 6, datetime.date(2024, 5, 8), Decimal('55.00'))
# (444, 2, 'finished', 3, datetime.date(2024, 7, 27), Decimal('53.00'))
# (445, 3, 'finished', 1, datetime.date(2024, 2, 27), Decimal('43.00'))
# (446, 10, 'finished', 8, datetime.date(2024, 9, 23), Decimal('14.00'))
# (447, 2, 'finished', 3, datetime.date(2024, 3, 5), Decimal('99.00'))
# (448, 4, 'finished', 9, datetime.date(2024, 10, 9), Decimal('9.00'))
# (449, 9, 'finished', 7, datetime.date(2024, 1, 7), Decimal('75.00'))
# (450, 1, 'finished', 2, datetime.date(2024, 1, 13), Decimal('13.00'))
# (451, 4, 'finished', 4, datetime.date(2024, 8, 20), Decimal('1.00'))
# (452, 9, 'finished', 8, datetime.date(2024, 8, 13), Decimal('9.00'))
# (453, 9, 'finished', 3, datetime.date(2024, 6, 12), Decimal('28.00'))
# (454, 4, 'finished', 3, datetime.date(2024, 9, 5), Decimal('37.00'))
# (455, 5, 'finished', 5, datetime.date(2024, 7, 24), Decimal('93.00'))
# (456, 10, 'finished', 3, datetime.date(2024, 8, 10), Decimal('78.00'))
# (457, 1, 'finished', 1, datetime.date(2024, 2, 17), Decimal('34.00'))
# (458, 3, 'finished', 3, datetime.date(2024, 4, 27), Decimal('40.00'))
# (459, 9, 'finished', 5, datetime.date(2024, 11, 28), Decimal('62.00'))
# (460, 8, 'finished', 3, datetime.date(2024, 7, 21), Decimal('74.00'))
# (461, 3, 'finished', 1, datetime.date(2024, 5, 12), Decimal('71.00'))
# (462, 4, 'finished', 6, datetime.date(2024, 1, 21), Decimal('21.00'))
# (463, 8, 'finished', 6, datetime.date(2024, 6, 16), Decimal('54.00'))
# (464, 7, 'finished', 4, datetime.date(2024, 3, 13), Decimal('65.00'))
# (465, 7, 'finished', 8, datetime.date(2024, 3, 24), Decimal('39.00'))
# (466, 8, 'finished', 8, datetime.date(2024, 6, 11), Decimal('66.00'))
# (467, 5, 'finished', 10, datetime.date(2024, 12, 5), Decimal('40.00'))
# (468, 9, 'finished', 2, datetime.date(2024, 12, 17), Decimal('58.00'))
# (469, 4, 'finished', 5, datetime.date(2024, 4, 10), Decimal('28.00'))
# (470, 4, 'finished', 10, datetime.date(2024, 6, 10), Decimal('71.00'))
# (471, 7, 'finished', 9, datetime.date(2024, 11, 25), Decimal('80.00'))
# (472, 9, 'finished', 8, datetime.date(2024, 8, 6), Decimal('78.00'))
# (473, 1, 'finished', 3, datetime.date(2024, 7, 15), Decimal('98.00'))
# (474, 2, 'finished', 2, datetime.date(2024, 11, 17), Decimal('25.00'))
# (475, 8, 'finished', 9, datetime.date(2024, 4, 25), Decimal('46.00'))
# (476, 10, 'finished', 7, datetime.date(2024, 8, 1), Decimal('88.00'))
# (477, 3, 'finished', 9, datetime.date(2024, 7, 9), Decimal('32.00'))
# (478, 10, 'finished', 4, datetime.date(2024, 7, 24), Decimal('51.00'))
# (479, 2, 'finished', 10, datetime.date(2024, 5, 11), Decimal('42.00'))
# (480, 9, 'finished', 6, datetime.date(2024, 11, 16), Decimal('38.00'))
# (481, 3, 'finished', 9, datetime.date(2024, 7, 24), Decimal('66.00'))
# (482, 9, 'finished', 3, datetime.date(2024, 6, 9), Decimal('91.00'))
# (483, 10, 'finished', 9, datetime.date(2024, 12, 16), Decimal('22.00'))
# (484, 6, 'finished', 10, datetime.date(2024, 6, 7), Decimal('67.00'))
# (485, 10, 'finished', 6, datetime.date(2024, 9, 13), Decimal('60.00'))
# (486, 6, 'finished', 6, datetime.date(2024, 9, 18), Decimal('8.00'))
# (487, 5, 'finished', 5, datetime.date(2024, 6, 7), Decimal('54.00'))
# (488, 6, 'finished', 3, datetime.date(2024, 4, 19), Decimal('14.00'))
# (489, 6, 'finished', 10, datetime.date(2024, 6, 28), Decimal('70.00'))
# (490, 1, 'finished', 6, datetime.date(2024, 6, 6), Decimal('22.00'))
# (491, 7, 'finished', 5, datetime.date(2024, 4, 7), Decimal('48.00'))
# (492, 5, 'finished', 3, datetime.date(2024, 4, 25), Decimal('21.00'))
# (493, 5, 'finished', 6, datetime.date(2024, 10, 13), Decimal('50.00'))
# (494, 7, 'finished', 4, datetime.date(2024, 8, 26), Decimal('92.00'))
# (495, 6, 'finished', 6, datetime.date(2024, 3, 23), Decimal('60.00'))
# (496, 1, 'finished', 2, datetime.date(2024, 7, 18), Decimal('55.00'))
# (497, 6, 'finished', 5, datetime.date(2024, 11, 7), Decimal('66.00'))
# (498, 10, 'finished', 7, datetime.date(2024, 7, 27), Decimal('71.00'))
# (499, 9, 'finished', 10, datetime.date(2024, 7, 19), Decimal('61.00'))
# (500, 2, 'finished', 1, datetime.date(2024, 3, 20), Decimal('41.00'))
# (501, 2, 'finished', 2, datetime.date(2024, 4, 12), Decimal('26.00'))
# (502, 4, 'finished', 10, datetime.date(2024, 5, 22), Decimal('68.00'))
# (503, 4, 'finished', 1, datetime.date(2024, 12, 22), Decimal('87.00'))
# (504, 6, 'finished', 5, datetime.date(2024, 3, 12), Decimal('59.00'))
# (505, 9, 'finished', 7, datetime.date(2024, 12, 16), Decimal('38.00'))
# (506, 1, 'finished', 7, datetime.date(2024, 7, 22), Decimal('1.00'))
# (507, 2, 'finished', 9, datetime.date(2024, 5, 5), Decimal('23.00'))
# (508, 3, 'finished', 8, datetime.date(2024, 6, 8), Decimal('7.00'))
# (509, 9, 'finished', 2, datetime.date(2024, 9, 16), Decimal('14.00'))
# (510, 5, 'finished', 5, datetime.date(2024, 9, 12), Decimal('49.00'))
# (511, 8, 'finished', 10, datetime.date(2024, 3, 28), Decimal('39.00'))
# (512, 7, 'finished', 9, datetime.date(2024, 12, 1), Decimal('98.00'))
# (513, 10, 'finished', 6, datetime.date(2024, 9, 24), Decimal('49.00'))
# (514, 9, 'finished', 9, datetime.date(2024, 3, 28), Decimal('15.00'))
# (515, 9, 'finished', 9, datetime.date(2024, 1, 11), Decimal('65.00'))
# (516, 3, 'finished', 3, datetime.date(2024, 6, 21), Decimal('60.00'))
# (517, 6, 'finished', 5, datetime.date(2024, 1, 27), Decimal('41.00'))
# (518, 9, 'finished', 9, datetime.date(2024, 5, 16), Decimal('84.00'))
# (519, 3, 'finished', 4, datetime.date(2024, 6, 22), Decimal('40.00'))
# (520, 3, 'finished', 7, datetime.date(2024, 3, 26), Decimal('11.00'))
# (521, 3, 'finished', 10, datetime.date(2024, 5, 11), Decimal('41.00'))
# (522, 10, 'finished', 3, datetime.date(2024, 3, 14), Decimal('16.00'))
# (523, 9, 'finished', 2, datetime.date(2024, 1, 18), Decimal('94.00'))
# (524, 5, 'finished', 5, datetime.date(2024, 4, 16), Decimal('17.00'))
# (525, 3, 'finished', 2, datetime.date(2024, 11, 27), Decimal('50.00'))
# (526, 9, 'finished', 6, datetime.date(2024, 3, 25), Decimal('56.00'))
# (527, 10, 'finished', 2, datetime.date(2024, 9, 1), Decimal('36.00'))
# (528, 3, 'finished', 2, datetime.date(2024, 1, 4), Decimal('7.00'))
# (529, 4, 'finished', 4, datetime.date(2024, 10, 27), Decimal('84.00'))
# (530, 9, 'finished', 9, datetime.date(2024, 1, 4), Decimal('49.00'))
# (531, 4, 'finished', 8, datetime.date(2024, 7, 14), Decimal('8.00'))
# (532, 5, 'finished', 1, datetime.date(2024, 4, 8), Decimal('42.00'))
# (533, 9, 'finished', 6, datetime.date(2024, 4, 12), Decimal('77.00'))
# (534, 7, 'finished', 3, datetime.date(2024, 6, 15), Decimal('72.00'))
# (535, 9, 'finished', 5, datetime.date(2024, 12, 12), Decimal('71.00'))
# (536, 4, 'finished', 6, datetime.date(2024, 8, 4), Decimal('56.00'))
# (537, 8, 'finished', 6, datetime.date(2024, 2, 14), Decimal('61.00'))
# (538, 3, 'finished', 2, datetime.date(2024, 8, 2), Decimal('7.00'))
# (539, 6, 'finished', 1, datetime.date(2024, 10, 8), Decimal('82.00'))
# (540, 10, 'finished', 6, datetime.date(2024, 11, 7), Decimal('32.00'))
# (541, 10, 'finished', 8, datetime.date(2024, 8, 9), Decimal('40.00'))
# (542, 9, 'finished', 6, datetime.date(2024, 12, 15), Decimal('80.00'))
# (543, 1, 'finished', 9, datetime.date(2024, 7, 24), Decimal('16.00'))
# (544, 10, 'finished', 4, datetime.date(2024, 8, 16), Decimal('40.00'))
# (545, 2, 'finished', 8, datetime.date(2024, 12, 12), Decimal('45.00'))
# (546, 9, 'finished', 10, datetime.date(2024, 8, 20), Decimal('78.00'))
# (547, 7, 'finished', 3, datetime.date(2024, 8, 28), Decimal('34.00'))
# (548, 3, 'finished', 7, datetime.date(2024, 3, 7), Decimal('70.00'))
# (549, 10, 'finished', 5, datetime.date(2024, 2, 1), Decimal('56.00'))
# (550, 6, 'finished', 8, datetime.date(2024, 6, 27), Decimal('35.00'))
# (551, 3, 'finished', 3, datetime.date(2024, 2, 18), Decimal('95.00'))
# (552, 9, 'finished', 3, datetime.date(2024, 10, 19), Decimal('97.00'))
# (553, 8, 'finished', 8, datetime.date(2024, 7, 18), Decimal('22.00'))
# (554, 8, 'finished', 2, datetime.date(2024, 6, 15), Decimal('76.00'))
# (555, 7, 'finished', 9, datetime.date(2024, 10, 21), Decimal('47.00'))
# (556, 5, 'finished', 1, datetime.date(2024, 7, 14), Decimal('44.00'))
# (557, 6, 'finished', 1, datetime.date(2024, 2, 12), Decimal('67.00'))
# (558, 2, 'finished', 6, datetime.date(2024, 3, 20), Decimal('15.00'))
# (559, 5, 'finished', 3, datetime.date(2024, 10, 16), Decimal('61.00'))
# (560, 8, 'finished', 6, datetime.date(2024, 8, 11), Decimal('16.00'))
# (561, 5, 'finished', 7, datetime.date(2024, 2, 24), Decimal('37.00'))
# (562, 10, 'finished', 3, datetime.date(2024, 12, 10), Decimal('99.00'))
# (563, 1, 'finished', 5, datetime.date(2024, 7, 21), Decimal('14.00'))
# (564, 9, 'finished', 6, datetime.date(2024, 7, 13), Decimal('72.00'))
# (565, 4, 'finished', 9, datetime.date(2024, 11, 13), Decimal('33.00'))
# (566, 8, 'finished', 1, datetime.date(2024, 12, 7), Decimal('40.00'))
# (567, 4, 'finished', 6, datetime.date(2024, 4, 15), Decimal('55.00'))
# (568, 9, 'finished', 4, datetime.date(2024, 10, 7), Decimal('51.00'))
# (569, 1, 'finished', 7, datetime.date(2024, 4, 11), Decimal('76.00'))
# (570, 6, 'finished', 8, datetime.date(2024, 8, 21), Decimal('33.00'))
# (571, 10, 'finished', 2, datetime.date(2024, 12, 4), Decimal('45.00'))
# (572, 8, 'finished', 7, datetime.date(2024, 2, 13), Decimal('28.00'))
# (573, 8, 'finished', 3, datetime.date(2024, 4, 2), Decimal('11.00'))
# (574, 2, 'finished', 6, datetime.date(2024, 7, 1), Decimal('62.00'))
# (575, 9, 'finished', 8, datetime.date(2024, 1, 7), Decimal('79.00'))
# (576, 1, 'finished', 8, datetime.date(2024, 12, 12), Decimal('27.00'))
# (577, 8, 'finished', 9, datetime.date(2024, 8, 22), Decimal('27.00'))
# (578, 1, 'finished', 2, datetime.date(2024, 2, 8), Decimal('83.00'))
# (579, 8, 'finished', 9, datetime.date(2024, 9, 4), Decimal('42.00'))
# (580, 5, 'finished', 9, datetime.date(2024, 7, 8), Decimal('30.00'))
# (581, 7, 'finished', 1, datetime.date(2024, 9, 6), Decimal('5.00'))
# (582, 3, 'finished', 2, datetime.date(2024, 8, 26), Decimal('74.00'))
# (583, 9, 'finished', 1, datetime.date(2024, 9, 4), Decimal('90.00'))
# (584, 4, 'finished', 9, datetime.date(2024, 1, 11), Decimal('23.00'))
# (585, 6, 'finished', 10, datetime.date(2024, 3, 6), Decimal('32.00'))
# (586, 7, 'finished', 6, datetime.date(2024, 1, 4), Decimal('54.00'))
# (587, 7, 'finished', 6, datetime.date(2024, 10, 18), Decimal('40.00'))
# (588, 10, 'finished', 6, datetime.date(2024, 8, 21), Decimal('61.00'))
# (589, 3, 'finished', 10, datetime.date(2024, 10, 22), Decimal('6.00'))
# (590, 3, 'finished', 4, datetime.date(2024, 11, 13), Decimal('41.00'))
# (591, 10, 'finished', 8, datetime.date(2024, 7, 16), Decimal('99.00'))
# (592, 9, 'finished', 4, datetime.date(2024, 2, 27), Decimal('42.00'))
# (593, 7, 'finished', 6, datetime.date(2024, 12, 7), Decimal('29.00'))
# (594, 4, 'finished', 8, datetime.date(2024, 4, 12), Decimal('6.00'))
# (595, 4, 'finished', 2, datetime.date(2024, 9, 20), Decimal('67.00'))
# (596, 9, 'finished', 7, datetime.date(2024, 11, 13), Decimal('37.00'))
# (597, 5, 'finished', 2, datetime.date(2024, 11, 18), Decimal('58.00'))
# (598, 7, 'finished', 2, datetime.date(2024, 7, 22), Decimal('84.00'))
# (599, 2, 'finished', 8, datetime.date(2024, 11, 9), Decimal('23.00'))
# (600, 1, 'finished', 2, datetime.date(2024, 8, 9), Decimal('31.00'))
